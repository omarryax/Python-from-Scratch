# %%
import calendar
month = int(input("Enter month"))
year = int(input("Enter year"))

# %%
cal = calendar.month(year, month)
print(cal)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cal = calendar.year(year)
#       2 print(cal)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\calendar.py:56, in __getattr__(name)
#      53     else:
#      54         return 2
# ---> 56 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'calendar' has no attribute 'year'

# %%
import math
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
math.sqrt(2)
math.unittest
math.
