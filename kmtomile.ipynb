# %%
km = float(input("Enter distance in kilometers: "))
print("Distance in kilometers: ", km)
miles = km * 0.62 
print ("Distance in miles: ", miles)
print(km, "km are equal to", miles, "miles")
# Out:
# Distance in kilometers:  5.0
# Distance in miles:  3.1
# 5.0 km are equal to 3.1 miles
