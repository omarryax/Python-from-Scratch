# %%
n = int(input("Enter number: "))
a = 0
b = 1

if n==0:
    print(a)
else:
    for i in range(1,n+1):
        next = a + b
        print(next)
        a = b
        b = next
# Out:
# 1
# 2
# 3
# 5
# 8
# 13
# 21
# 34
