# %%
greater = 0
lower = 0
def compute_lcm(x, y):
    if x>y:
        greater = x
    else:
        greater = y
    while(True):
        if (greater % x == 0) and (greater % y == 0):
            lcm = greater
            break
        greater += 1
    return lcm

x = int(input("Enter first number: "))
y= int(input("Enter second number: "))
print("The L.C.M. of",x,"and",y,"is",compute_lcm(n1, n2))
# Out:
# The L.C.M. of 23 and 24 is 552
